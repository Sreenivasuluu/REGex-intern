# %% [markdown]
# # "Perform Data Preprocessing and Analysis on Carbon_Emmissions dataset"

# %% [markdown]
# ## (a) Preprocessing the data

# %% [markdown]
# ### i. Import the required Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %% [markdown]
# ### ii. Import the data set

# %%
df = pd.read_csv(r'/Users/Sreenivasulu/reg_ds_class/CO2_Emissions_Canada.csv')
df
# Out:
#        Make        Model   Vehicle Class  Engine Size(L)  Cylinders  \
# 0     ACURA          ILX         COMPACT             2.0          4
# 1     ACURA          ILX         COMPACT             2.4          4
# 2     ACURA   ILX HYBRID         COMPACT             1.5          4
# 3     ACURA      MDX 4WD     SUV - SMALL             3.5          6
# 4     ACURA      RDX AWD     SUV - SMALL             3.5          6
# ...     ...          ...             ...             ...        ...
# 7380  VOLVO  XC40 T5 AWD     SUV - SMALL             2.0          4
# 7381  VOLVO  XC60 T5 AWD     SUV - SMALL             2.0          4
# 7382  VOLVO  XC60 T6 AWD     SUV - SMALL             2.0          4
# 7383  VOLVO  XC90 T5 AWD  SUV - STANDARD             2.0          4
# 7384  VOLVO  XC90 T6 AWD  SUV - STANDARD             2.0          4
#
#      Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 0             AS5         Z                               9.9
# ...

# %%
df.describe()
# Out:
#        Engine Size(L)    Cylinders  Fuel Consumption City (L/100 km)  \
# count     7385.000000  7385.000000                       7385.000000
# mean         3.160068     5.615030                         12.556534
# std          1.354170     1.828307                          3.500274
# min          0.900000     3.000000                          4.200000
# 25%          2.000000     4.000000                         10.100000
# 50%          3.000000     6.000000                         12.100000
# 75%          3.700000     6.000000                         14.600000
# max          8.400000    16.000000                         30.600000
#
#        Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# count                      7385.000000                       7385.000000
# mean                          9.041706                         10.975071
# std                           2.224456                          2.892506
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7385 entries, 0 to 7384
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Make                              7385 non-null   object
#  1   Model                             7385 non-null   object
#  2   Vehicle Class                     7385 non-null   object
#  3   Engine Size(L)                    7385 non-null   float64
#  4   Cylinders                         7385 non-null   int64
#  5   Transmission                      7385 non-null   object
#  6   Fuel Type                         7385 non-null   object
#  7   Fuel Consumption City (L/100 km)  7385 non-null   float64
#  8   Fuel Consumption Hwy (L/100 km)   7385 non-null   float64
#  9   Fuel Consumption Comb (L/100 km)  7385 non-null   float64
#  10  Fuel Consumption Comb (mpg)       7385 non-null   int64
# ...

# %%
df.nunique()
# Out:
# Make                                  42
# Model                               2053
# Vehicle Class                         16
# Engine Size(L)                        51
# Cylinders                              8
# Transmission                          27
# Fuel Type                              5
# Fuel Consumption City (L/100 km)     211
# Fuel Consumption Hwy (L/100 km)      143
# Fuel Consumption Comb (L/100 km)     181
# Fuel Consumption Comb (mpg)           54
# CO2 Emissions(g/km)                  331
# dtype: int64

# %% [markdown]
# ### iii. Handling duplicated and Missing data

# %%
df.duplicated().sum()
# Out:
# 1103

# %%
df.drop_duplicates(inplace=True)       # dropping the duplicated rows

# %%
df
# Out:
#        Make        Model   Vehicle Class  Engine Size(L)  Cylinders  \
# 0     ACURA          ILX         COMPACT             2.0          4
# 1     ACURA          ILX         COMPACT             2.4          4
# 2     ACURA   ILX HYBRID         COMPACT             1.5          4
# 3     ACURA      MDX 4WD     SUV - SMALL             3.5          6
# 4     ACURA      RDX AWD     SUV - SMALL             3.5          6
# ...     ...          ...             ...             ...        ...
# 7380  VOLVO  XC40 T5 AWD     SUV - SMALL             2.0          4
# 7381  VOLVO  XC60 T5 AWD     SUV - SMALL             2.0          4
# 7382  VOLVO  XC60 T6 AWD     SUV - SMALL             2.0          4
# 7383  VOLVO  XC90 T5 AWD  SUV - STANDARD             2.0          4
# 7384  VOLVO  XC90 T6 AWD  SUV - STANDARD             2.0          4
#
#      Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 0             AS5         Z                               9.9
# ...

# %% [markdown]
# ### Check for null values

# %%
df.isnull().sum()
# Out:
# Make                                0
# Model                               0
# Vehicle Class                       0
# Engine Size(L)                      0
# Cylinders                           0
# Transmission                        0
# Fuel Type                           0
# Fuel Consumption City (L/100 km)    0
# Fuel Consumption Hwy (L/100 km)     0
# Fuel Consumption Comb (L/100 km)    0
# Fuel Consumption Comb (mpg)         0
# CO2 Emissions(g/km)                 0
# dtype: int64

# %%
# No null values in the dataset

# %% [markdown]
# ### iv. Encoding Categorical Data

# %%
# Change the all categorical values into numeric values as ML supports only numericals

# %%
# Here the hypothesis is 'Make','Model' won't effect the 'CO2 Emissions' but specifications does

X = df[['Vehicle Class','Transmission','Fuel Type','Engine Size(L)','Cylinders','Fuel Consumption Comb (L/100 km)']]
Y = df[['CO2 Emissions(g/km)']]

X.head()
# Out:
#   Vehicle Class Transmission Fuel Type  Engine Size(L)  Cylinders  \
# 0       COMPACT          AS5         Z             2.0          4
# 1       COMPACT           M6         Z             2.4          4
# 2       COMPACT          AV7         Z             1.5          4
# 3   SUV - SMALL          AS6         Z             3.5          6
# 4   SUV - SMALL          AS6         Z             3.5          6
#
#    Fuel Consumption Comb (L/100 km)
# 0                               8.5
# 1                               9.6
# 2                               5.9
# 3                              11.1
# 4                              10.6

# %%
from sklearn.preprocessing import OrdinalEncoder
col = ['Vehicle Class','Transmission','Fuel Type']
oe = OrdinalEncoder()
X[col] = oe.fit_transform(X[col])

# %%
X
# Out:
#       Vehicle Class  Transmission  Fuel Type  Engine Size(L)  Cylinders  \
# 0               0.0          14.0        4.0             2.0          4
# 1               0.0          25.0        4.0             2.4          4
# 2               0.0          22.0        4.0             1.5          4
# 3              11.0          15.0        4.0             3.5          6
# 4              11.0          15.0        4.0             3.5          6
# ...             ...           ...        ...             ...        ...
# 7380           11.0          17.0        4.0             2.0          4
# 7381           11.0          17.0        4.0             2.0          4
# 7382           11.0          17.0        4.0             2.0          4
# 7383           12.0          17.0        4.0             2.0          4
# 7384           12.0          17.0        4.0             2.0          4
#
#       Fuel Consumption Comb (L/100 km)
# 0                                  8.5
# ...

# %% [markdown]
# ### v. Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
cols = ['Engine Size(L)','Cylinders','Fuel Consumption Comb (L/100 km)']
X[cols]=sc.fit_transform(X[cols])
print(X.shape)
X
# Out:
# (6282, 6)
#       Vehicle Class  Transmission  Fuel Type  Engine Size(L)  Cylinders  \
# 0               0.0          14.0        4.0       -0.851086  -0.876934
# 1               0.0          25.0        4.0       -0.558066  -0.876934
# 2               0.0          22.0        4.0       -1.217362  -0.876934
# 3              11.0          15.0        4.0        0.247740   0.206429
# 4              11.0          15.0        4.0        0.247740   0.206429
# ...             ...           ...        ...             ...        ...
# 7380           11.0          17.0        4.0       -0.851086  -0.876934
# 7381           11.0          17.0        4.0       -0.851086  -0.876934
# 7382           11.0          17.0        4.0       -0.851086  -0.876934
# 7383           12.0          17.0        4.0       -0.851086  -0.876934
# 7384           12.0          17.0        4.0       -0.851086  -0.876934
#
#       Fuel Consumption Comb (L/100 km)
# 0                            -0.854490
# ...

# %%
print(Y.shape)
Y
# Out:
# (6282, 1)
#       CO2 Emissions(g/km)
# 0                     196
# 1                     221
# 2                     136
# 3                     255
# 4                     244
# ...                   ...
# 7380                  219
# 7381                  232
# 7382                  240
# 7383                  232
# 7384                  248
#
# [6282 rows x 1 columns]

# %% [markdown]
# ### vi. Splitting the dataset into test set and training set

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.45)

# %%
X_train
# Out:
#       Vehicle Class  Transmission  Fuel Type  Engine Size(L)  Cylinders  \
# 5912            2.0          19.0        3.0       -1.217362  -0.876934
# 6246           10.0          25.0        4.0       -0.851086  -0.876934
# 495            13.0          25.0        3.0       -1.217362  -0.876934
# 2607           12.0          15.0        3.0        0.247740   0.206429
# 3413            1.0          17.0        4.0        0.907036   1.289792
# ...             ...           ...        ...             ...        ...
# 4349            0.0          17.0        3.0       -0.851086  -0.876934
# 1275            2.0          15.0        4.0       -0.851086  -0.876934
# 1996            3.0          26.0        4.0        0.467506   0.206429
# 1142            2.0          17.0        4.0        0.614016   1.289792
# 1327           15.0           3.0        3.0        2.079118   1.289792
#
#       Fuel Consumption Comb (L/100 km)
# 5912                         -2.076220
# ...

# %%
Y_train
# Out:
#       CO2 Emissions(g/km)
# 5912                  114
# 6246                  210
# 495                   159
# 2607                  303
# 3413                  292
# ...                   ...
# 4349                  219
# 1275                  228
# 1996                  258
# 1142                  281
# 1327                  437
#
# [3455 rows x 1 columns]

# %%
X_test
# Out:
#       Vehicle Class  Transmission  Fuel Type  Engine Size(L)  Cylinders  \
# 901            12.0           5.0        4.0        1.200057   1.289792
# 111             1.0           5.0        4.0        0.907036   1.289792
# 2431           11.0           3.0        3.0       -0.558066  -0.876934
# 5177           13.0           6.0        4.0       -0.118535   0.206429
# 1945           13.0          16.0        4.0        0.394251   0.206429
# ...             ...           ...        ...             ...        ...
# 5073            2.0          15.0        3.0       -0.851086  -0.876934
# 2603           10.0          24.0        3.0       -1.144107  -0.876934
# 4408            1.0          17.0        4.0        0.614016   1.289792
# 5378            2.0          21.0        3.0       -0.484811  -0.876934
# 3884           11.0           6.0        3.0       -0.558066  -0.876934
#
#       Fuel Consumption Comb (L/100 km)
# 901                           1.419285
# ...

# %%
Y_test
# Out:
#       CO2 Emissions(g/km)
# 901                   358
# 111                   292
# 2431                  235
# 5177                  238
# 1945                  264
# ...                   ...
# 5073                  242
# 2603                  179
# 4408                  290
# 5378                  121
# 3884                  235
#
# [2827 rows x 1 columns]

# %% [markdown]
# ## (b) Analysing the data

# %%
df
# Out:
#        Make        Model   Vehicle Class  Engine Size(L)  Cylinders  \
# 0     ACURA          ILX         COMPACT             2.0          4
# 1     ACURA          ILX         COMPACT             2.4          4
# 2     ACURA   ILX HYBRID         COMPACT             1.5          4
# 3     ACURA      MDX 4WD     SUV - SMALL             3.5          6
# 4     ACURA      RDX AWD     SUV - SMALL             3.5          6
# ...     ...          ...             ...             ...        ...
# 7380  VOLVO  XC40 T5 AWD     SUV - SMALL             2.0          4
# 7381  VOLVO  XC60 T5 AWD     SUV - SMALL             2.0          4
# 7382  VOLVO  XC60 T6 AWD     SUV - SMALL             2.0          4
# 7383  VOLVO  XC90 T5 AWD  SUV - STANDARD             2.0          4
# 7384  VOLVO  XC90 T6 AWD  SUV - STANDARD             2.0          4
#
#      Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 0             AS5         Z                               9.9
# ...

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Vehicle Class', 'Engine Size(L)', 'Cylinders',
#        'Transmission', 'Fuel Type', 'Fuel Consumption City (L/100 km)',
#        'Fuel Consumption Hwy (L/100 km)', 'Fuel Consumption Comb (L/100 km)',
#        'Fuel Consumption Comb (mpg)', 'CO2 Emissions(g/km)'],
#       dtype='object')

# %%
df.nunique()
# Out:
# Make                                  42
# Model                               2053
# Vehicle Class                         16
# Engine Size(L)                        51
# Cylinders                              8
# Transmission                          27
# Fuel Type                              5
# Fuel Consumption City (L/100 km)     211
# Fuel Consumption Hwy (L/100 km)      143
# Fuel Consumption Comb (L/100 km)     181
# Fuel Consumption Comb (mpg)           54
# CO2 Emissions(g/km)                  331
# dtype: int64

# %%
plt.figure(figsize=(12,12),dpi=200)
order = df.groupby(['Make']).mean().sort_values('CO2 Emissions(g/km)',ascending=False).index
sns.barplot(df['CO2 Emissions(g/km)'],df['Make'], order = order)
# Out:
# <AxesSubplot:xlabel='CO2 Emissions(g/km)', ylabel='Make'>

# %%
plt.figure(dpi=200)
order = df.groupby(['Fuel Type']).mean().sort_values('CO2 Emissions(g/km)',ascending=False).index
sns.barplot(df['Fuel Type'],df['CO2 Emissions(g/km)'], order = order)
# Out:
# <AxesSubplot:xlabel='Fuel Type', ylabel='CO2 Emissions(g/km)'>

# %%
plt.figure(figsize=(10,20),dpi=200)
order = df.groupby(['Make']).mean().sort_values('CO2 Emissions(g/km)',ascending=False).index
sns.barplot(df['CO2 Emissions(g/km)'],df['Make'],hue = df['Fuel Type'], order = order)
# Out:
# <AxesSubplot:xlabel='CO2 Emissions(g/km)', ylabel='Make'>

# %% [markdown]
# # Observation :
#    ## The vehicles Made by  ['BUGATTI', 'LAMBORGHINI', 'SRT', 'ROLLS-ROYCE', 'BENTLEY','ASTON MARTIN',] with fuel type ['Z'] are producing the higher Emissions

# %%
plt.figure(figsize=(8,10),dpi=200)
Order = df.groupby(['Vehicle Class']).mean().sort_values('CO2 Emissions(g/km)',ascending = False).index
sns.barplot(df['CO2 Emissions(g/km)'],df['Vehicle Class'],hue = df['Fuel Type'],order = Order)
# Out:
# <AxesSubplot:xlabel='CO2 Emissions(g/km)', ylabel='Vehicle Class'>

# %% [markdown]
# # Observation :
#    ## The Vehicle Class 'VAN - PASSENGER', 'VAN - CARGO' with fuel type 'X','E' produces high Emissions

# %%
plt.figure(figsize=(12,6),dpi=200)
orde = df.groupby('Transmission').mean().sort_values('CO2 Emissions(g/km)',ascending = False).index
chart = sns.barplot(df['Transmission'],df['CO2 Emissions(g/km)'], order = orde)
chart.axhline(200)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
plt.show()

# %% [markdown]
# # Observation :
#    ## The transmissions 'M5', 'AV7','AV6', 'AM6', 'AV10', 'AV', 'AM5' are with minimum affordable emissions

# %%
plt.figure(figsize=(15,7))
sns.barplot(df['Cylinders'],df['CO2 Emissions(g/km)'],hue = df['Fuel Type'])
plt.show()

# %%
plt.figure(figsize=(12,6),dpi=200)
sns.lineplot(y=df['CO2 Emissions(g/km)'],x=df['Engine Size(L)'])
# Out:
# <AxesSubplot:xlabel='Engine Size(L)', ylabel='CO2 Emissions(g/km)'>

# %% [markdown]
# # Observation :
#    ## As the no.of cylinders and Engine size(L) increases, the emissions will increases and high no.of cylinders uses mostly 'Z' type fuel

# %%
plt.figure(figsize=(12,6),dpi=200)
sns.barplot(df['Fuel Type'],df['CO2 Emissions(g/km)'],hue=df['Cylinders'])
# Out:
# <AxesSubplot:xlabel='Fuel Type', ylabel='CO2 Emissions(g/km)'>

# %% [markdown]
# # Observation :
#    ## The 'Z' and 'X' type fuels are mostly used in all vehicles and in that with high no.of cylinders, they produce high emission content

# %%
plt.figure(figsize=(12,6),dpi=200)
chart = sns.lineplot(df['Engine Size(L)'],df['CO2 Emissions(g/km)'],label = 'Engine_Size')
chart = sns.lineplot(df['Cylinders'],df['CO2 Emissions(g/km)'], label = 'No.of_Cylinders')
plt.xlabel(' ')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,6),dpi=200)
chart = sns.lineplot(df['Fuel Consumption City (L/100 km)'],df['CO2 Emissions(g/km)'],label = 'City')
chart = sns.lineplot(df['Fuel Consumption Hwy (L/100 km)'],df['CO2 Emissions(g/km)'], label = 'Hwy')
chart = sns.lineplot(df['Fuel Consumption Comb (L/100 km)'],df['CO2 Emissions(g/km)'], label = 'Comb')
plt.xlabel('Fuel Consumption (L/100 km)')
plt.show()

# %% [markdown]
# # Observation :
#    ## - The emission rate increases with increasing in Fuel consumption (L/100)
#    ## - City has the high Fuel consumption (L/100) followed by Comb and Hwy

# %%
plt.figure(figsize=(12,6),dpi=200)
sns.lineplot(df['Fuel Consumption Comb (mpg)'],df['CO2 Emissions(g/km)'])
plt.xlim(df['Fuel Consumption Comb (mpg)'].max(),df['Fuel Consumption Comb (mpg)'].min())
# Out:
# (69.0, 11.0)

# %% [markdown]
# # Observation :
#    ## Lower the mileage of vehicle higher the emission rate, so it should be better to have high mileage vehicle for reducing the emissions

# %%
cor = df.corr()
heatmap = sns.heatmap(cor, annot=True , cmap='OrRd')

heatmap.set_title('Cars Heatmap', fontdict={'fontsize':18}, pad=12);

# %% [markdown]
# # Observation :
#    ## - The mileage[Fuel Consumption Comb (mpg)] is negatively corelated with almost all other features (it's simple logic)
#    ## - Every feature is highly related with each other and also with emission rate

# %%
plt.figure(dpi=200)
sns.violinplot(y = df['CO2 Emissions(g/km)'])
# Out:
# <AxesSubplot:ylabel='CO2 Emissions(g/km)'>
